# %% [markdown]
# 홈페이지에서 .csv 파일 다운받아 dataframe 생성

# %%
import pandas as pd

# Daraframe형식으로 csv 파일 읽기
df_2023 = pd.read_csv("../data/2023.01_2023.12.csv", encoding='cp949')
df_2022 = pd.read_csv("../data/2022.01_2022.12.csv", encoding='cp949')
df_2021 = pd.read_csv("../data/2021.01_2021.12.csv", encoding='cp949')
df_2020 = pd.read_csv("../data/2020.01_2020.12.csv", encoding='cp949')
df_2019 = pd.read_csv("../data/2019.01_2019.12.csv", encoding='cp949')
df_2018 = pd.read_csv("../data/2018.01_2018.12.csv", encoding='cp949')
df_2017 = pd.read_csv("../data/2017.01_2017.12.csv", encoding='cp949')
df_2016 = pd.read_csv("../data/2016.01_2016.12.csv", encoding='cp949')
df_2015 = pd.read_csv("../data/2015.01_2015.12.csv", encoding='cp949')
df_2014 = pd.read_csv("../data/2014.01_2014.12.csv", encoding='cp949')
df_2013 = pd.read_csv("../data/2013.01_2013.12.csv", encoding='cp949')
df_2012 = pd.read_csv("../data/2012.01_2012.12.csv", encoding='cp949')
df_2011 = pd.read_csv("../data/2011.01_2011.12.csv", encoding='cp949')
df_2010 = pd.read_csv("../data/2010.01_2010.12.csv", encoding='cp949')
df_2009 = pd.read_csv("../data/2009.01_2009.12.csv", encoding='cp949')
df_2008 = pd.read_csv("../data/2008.01_2008.12.csv", encoding='cp949')
df_2007 = pd.read_csv("../data/2007.01_2007.12.csv", encoding='cp949')
df_2006 = pd.read_csv("../data/2006.01_2006.12.csv", encoding='cp949')

# %%
# 데이터 프레임 출력
df_2022
# Out:
#              일자       시가총액_전체   시가총액_외국인보유  시가총액_비율      주식수_전체   주식수_외국인보유  \
# 0    2022/12/29  1.767235e+09  543944545.0    30.78  63527819.0  11342203.0
# 1    2022/12/28  1.801878e+09  555436503.0    30.83  63530859.0  11352455.0
# 2    2022/12/27  1.844141e+09  570257748.0    30.92  63457089.0  11320267.0
# 3    2022/12/26  1.831728e+09  566863427.0    30.95  63440079.0  11322007.0
# 4    2022/12/23  1.829396e+09  567604299.0    31.03  63437891.0  11331991.0
# ..          ...           ...          ...      ...         ...         ...
# 241  2022/01/07  2.187561e+09  737665725.0    33.72  61993025.0  11338048.0
# 242  2022/01/06  2.162437e+09  728441194.0    33.69  61992904.0  11339554.0
# 243  2022/01/05  2.186715e+09  733769920.0    33.56  61980090.0  11345102.0
# 244  2022/01/04  2.212088e+09  742178062.0    33.55  61979896.0  11338758.0
# 245  2022/01/03  2.211373e+09  740881208.0    33.50  61979896.0  11321408.0
#
#      주식수_비율
# 0     17.85
# 1     17.87
# 2     17.84
# ...

# %%
# 불러온 데이터 프레임 합치기

df_total = pd.concat([df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023])

df_total #DATE/ MARKET_CAP/ MARKET_CAP_FOREIGNER/MARKET_CAP_PERCENT/ NUM_OF_STOCKS_TOTAL/N.O.S_FOREIGNER/N.O.S_PERCENT
# Out:
#              일자       시가총액_전체   시가총액_외국인보유  시가총액_비율      주식수_전체   주식수_외국인보유  \
# 0    2006/12/28  7.045354e+08  262290953.0    37.23  24960515.0   5521620.0
# 1    2006/12/27  6.999730e+08  260873606.0    37.27  24975636.0   5519580.0
# 2    2006/12/26  7.037860e+08  262933045.0    37.36  24956117.0   5515578.0
# 3    2006/12/22  7.050552e+08  262836476.0    37.28  24850186.0   5512771.0
# 4    2006/12/21  7.047444e+08  262733926.0    37.28  24920672.0   5502920.0
# ..          ...           ...          ...      ...         ...         ...
# 240  2023/01/06  1.811419e+09  569826771.0    31.46  63748154.0  11363988.0
# 241  2023/01/05  1.791817e+09  561953198.0    31.36  63736154.0  11355206.0
# 242  2023/01/04  1.783809e+09  556856308.0    31.22  63547940.0  11351843.0
# 243  2023/01/03  1.753771e+09  542125996.0    30.91  63547940.0  11329343.0
# 244  2023/01/02  1.759242e+09  542199970.0    30.82  63527933.0  11334974.0
#
#      주식수_비율
# 0     22.12
# 1     22.10
# 2     22.10
# ...

# %%
#2023년도 일별 외국인 투자자가 가지고 있던 주식수 비율 총합

df_2023_sum = df_total[df_total['일자'].str.contains('2023')]

df_2023_mean = df_2023_sum['주식수_비율'].sum() /249

# %%
#2006년~2023년도 외국인 투자자가 가지고 있던 주식수 비율 총합

df_2022_sum = df_total[df_total['일자'].str.contains('2022')]
df_2021_sum = df_total[df_total['일자'].str.contains('2021')]
df_2020_sum = df_total[df_total['일자'].str.contains('2020')]
df_2019_sum = df_total[df_total['일자'].str.contains('2019')]
df_2018_sum = df_total[df_total['일자'].str.contains('2018')]
df_2017_sum = df_total[df_total['일자'].str.contains('2017')]
df_2016_sum = df_total[df_total['일자'].str.contains('2016')]
df_2015_sum = df_total[df_total['일자'].str.contains('2015')]
df_2014_sum = df_total[df_total['일자'].str.contains('2014')]
df_2013_sum = df_total[df_total['일자'].str.contains('2013')]
df_2012_sum = df_total[df_total['일자'].str.contains('2012')]
df_2011_sum = df_total[df_total['일자'].str.contains('2011')]
df_2010_sum = df_total[df_total['일자'].str.contains('2010')]
df_2009_sum = df_total[df_total['일자'].str.contains('2009')]
df_2008_sum = df_total[df_total['일자'].str.contains('2008')]
df_2007_sum = df_total[df_total['일자'].str.contains('2007')]
df_2006_sum = df_total[df_total['일자'].str.contains('2006')]

# %%
#연단위 일별 외국인 보유 주식수 총합/평일일수

df_2022_mean = df_2022_sum['주식수_비율'].sum()/269
df_2021_mean = df_2021_sum['주식수_비율'].sum()/269
df_2020_mean = df_2020_sum['주식수_비율'].sum()/269
df_2019_mean = df_2019_sum['주식수_비율'].sum()/269
df_2018_mean = df_2018_sum['주식수_비율'].sum()/269
df_2017_mean = df_2017_sum['주식수_비율'].sum()/269
df_2016_mean = df_2016_sum['주식수_비율'].sum()/269
df_2015_mean = df_2015_sum['주식수_비율'].sum()/269
df_2014_mean = df_2014_sum['주식수_비율'].sum()/269
df_2013_mean = df_2013_sum['주식수_비율'].sum()/269
df_2012_mean = df_2012_sum['주식수_비율'].sum()/269
df_2011_mean = df_2011_sum['주식수_비율'].sum()/269
df_2010_mean = df_2010_sum['주식수_비율'].sum()/269
df_2009_mean = df_2009_sum['주식수_비율'].sum()/269
df_2008_mean = df_2008_sum['주식수_비율'].sum()/269
df_2007_mean = df_2007_sum['주식수_비율'].sum()/269
df_2006_mean = df_2006_sum['주식수_비율'].sum()/269

# %%
import pandas as pd

year = ['2006', '2007',  '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']    
mean = [df_2006_mean, df_2007_mean, df_2008_mean, df_2009_mean, df_2010_mean, df_2011_mean, df_2012_mean, df_2013_mean, df_2014_mean, df_2015_mean, df_2016_mean, df_2017_mean, df_2018_mean, df_2019_mean, df_2020_mean, df_2021_mean, df_2022_mean, df_2023_mean]


df_mean = pd.DataFrame(data = list(zip(year, mean)), columns = ["YEAR", "MEAN"])
df_mean
# Out:
#     YEAR       MEAN
# 0   2006  20.928439
# 1   2007  19.554164
# 2   2008  16.033271
# 3   2009  14.795874
# 4   2010  15.220595
# 5   2011  15.176134
# 6   2012  14.410000
# 7   2013  14.650483
# 8   2014  15.232862
# 9   2015  15.760929
# 10  2016  14.846654
# 11  2017  15.260595
# 12  2018  18.812342
# 13  2019  20.346877
# 14  2020  18.648959
# 15  2021  17.253086
# 16  2022  16.590818
# 17  2023  18.166104

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

plt.figure(figsize=(35, 15))

# 연평균 외국인 보유 주식수 데이터에 대한 선 그래프
bar_plot = plt.bar(df_mean['YEAR'], df_mean['MEAN'], color='blue', alpha=0.7)
plt.xlabel('년', fontsize=20, labelpad=20)
plt.xticks(fontsize=16)
plt.ylabel('연평균 외국인 보유 주식수(%)', fontsize=20, labelpad=20)
plt.yticks(fontsize=16)
plt.tick_params(axis='y', labelcolor='black')
#plt.legend(loc='upper left')

plt.show()
# Out:
# /home/yean/venv/eda_venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yean/venv/eda_venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yean/venv/eda_venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/yean/venv/eda_venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
#코스피 연평균 외국인투자자 보유 주식수 비율 dataframe을 mysql에 저장

import mysql.connector

remote = mysql.connector.connect(
    host = "database-1.c5m0wusgusk6.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "0000",
    database = "amrbase"
)

# %%
sql = """INSERT INTO KOSDAQ_MARKET_01 VALUES (%s, %s, %s)"""
cursor = remote.cursor(buffered=True)

# %%
for i, row in total_result_df_01.iterrows():
    cursor.execute(sql, tuple(row))
    print(tuple(row))
    remote.commit()

# %%
sql_2 = """INSERT INTO KOSDAQ_MARKET_02 VALUES (%s, %s, %s, %s, %s)"""
cursor = remote.cursor(buffered=True)

# %%
for i, row in total_result_df_02.iterrows():
    cursor.execute(sql_2, tuple(row))
    print(tuple(row))
    remote.commit()
